# %% [markdown]
# # Introduction to Regression with Neural Networks in Tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# ## Creating data to view and fit

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0]).reshape(-1,1)
y = np.array([3.0, 6.0, 9.0, 12.0, 15., 18., 21., 24. ]).reshape(-1,1)

plt.scatter(X,y)

# %% [markdown]
# ## Input and output shapes

# %%
house_info = tf.constant(["bedroom", "bathroom", "garage"])
house_price = tf.constant([939700])
house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
X = tf.cast(tf.constant(X), dtype=tf.float32)
y = tf.cast(tf.constant(y), dtype=tf.float32)
X, y
# Out:
# (<tf.Tensor: shape=(8, 1), dtype=float32, numpy=
#  array([[-7.],
#         [-4.],
#         [-1.],
#         [ 2.],
#         [ 5.],
#         [ 8.],
#         [11.],
#         [14.]], dtype=float32)>,
#  <tf.Tensor: shape=(8, 1), dtype=float32, numpy=
#  array([[ 3.],
#         [ 6.],
#         [ 9.],
#         [12.],
#         [15.],
#         [18.],
#         [21.],
#         [24.]], dtype=float32)>)

# %% [markdown]
# ## Steps in modelling with Tensorflow

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics=["mae"])

model.fit(X, y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 5s 5s/step - loss: 11.5048 - mae: 11.5048
# Epoch 2/5
# 1/1 [==============================] - 0s 18ms/step - loss: 11.3723 - mae: 11.3723
# Epoch 3/5
# 1/1 [==============================] - 0s 19ms/step - loss: 11.2398 - mae: 11.2398
# Epoch 4/5
# 1/1 [==============================] - 0s 22ms/step - loss: 11.1073 - mae: 11.1073
# Epoch 5/5
# 1/1 [==============================] - 0s 16ms/step - loss: 10.9748 - mae: 10.9748

# %%
X, y
# Out:
# (<tf.Tensor: shape=(8, 1), dtype=float32, numpy=
#  array([[-7.],
#         [-4.],
#         [-1.],
#         [ 2.],
#         [ 5.],
#         [ 8.],
#         [11.],
#         [14.]], dtype=float32)>,
#  <tf.Tensor: shape=(8, 1), dtype=float32, numpy=
#  array([[ 3.],
#         [ 6.],
#         [ 9.],
#         [12.],
#         [15.],
#         [18.],
#         [21.],
#         [24.]], dtype=float32)>)

# %%
y_pred = model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 253ms/step

# %% [markdown]
# ## Improving our model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
               optimizer=tf.keras.optimizers.SGD(),
               metrics=["mae"])

model.fit(X,y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 832ms/step - loss: 11.2219 - mae: 11.2219
# Epoch 2/100
# 1/1 [==============================] - 0s 17ms/step - loss: 11.0894 - mae: 11.0894
# Epoch 3/100
# 1/1 [==============================] - 0s 26ms/step - loss: 10.9569 - mae: 10.9569
# Epoch 4/100
# 1/1 [==============================] - 0s 19ms/step - loss: 10.8244 - mae: 10.8244
# Epoch 5/100
# 1/1 [==============================] - 0s 16ms/step - loss: 10.6919 - mae: 10.6919
# Epoch 6/100
# 1/1 [==============================] - 0s 13ms/step - loss: 10.5594 - mae: 10.5594
# Epoch 7/100
# 1/1 [==============================] - 0s 16ms/step - loss: 10.4269 - mae: 10.4269
# Epoch 8/100
# 1/1 [==============================] - 0s 14ms/step - loss: 10.2944 - mae: 10.2944
# Epoch 9/100
# 1/1 [==============================] - 0s 13ms/step - loss: 10.1619 - mae: 10.1619
# Epoch 10/100
# 1/1 [==============================] - 0s 12ms/step - loss: 10.0294 - mae: 10.0294
# Epoch 11/100
# 1/1 [==============================] - 0s 20ms/step - loss: 9.8969 - mae: 9.8969
# Epoch 12/100
# 1/1 [==============================] - 0s 14ms/step - loss: 9.7644 - mae: 9.7644
# Epoch 13/100
# 1/1 [==============================] - 0s 11ms/step - loss: 9.6319 - mae: 9.6319
# Epoch 14/100
# 1/1 [==============================] - 0s 11ms/step - loss: 9.4994 - mae: 9.4994
# Epoch 15/100
# 1/1 [==============================] - 0s 18ms/step - loss: 9.3669 - mae: 9.3669
# Epoch 16/100
# 1/1 [==============================] - 0s 9ms/step - loss: 9.2344 - mae: 9.2344
# Epoch 17/100
# 1/1 [==============================] - 0s 17ms/step - loss: 9.1019 - mae: 9.1019
# Epoch 18/100
# 1/1 [==============================] - 0s 18ms/step - loss: 8.9694 - mae: 8.9694
# Epoch 19/100
# 1/1 [==============================] - 0s 24ms/step - loss: 8.8369 - mae: 8.8369
# Epoch 20/100
# 1/1 [==============================] - 0s 15ms/step - loss: 8.7044 - mae: 8.7044
# Epoch 21/100
# 1/1 [==============================] - 0s 14ms/step - loss: 8.5719 - mae: 8.5719
# Epoch 22/100
# 1/1 [==============================] - 0s 15ms/step - loss: 8.4394 - mae: 8.4394
# Epoch 23/100
# 1/1 [==============================] - 0s 14ms/step - loss: 8.3069 - mae: 8.3069
# Epoch 24/100
# 1/1 [==============================] - 0s 18ms/step - loss: 8.1744 - mae: 8.1744
# Epoch 25/100
# 1/1 [==============================] - 0s 13ms/step - loss: 8.0419 - mae: 8.0419
# Epoch 26/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.9094 - mae: 7.9094
# Epoch 27/100
# 1/1 [==============================] - 0s 13ms/step - loss: 7.7769 - mae: 7.7769
# Epoch 28/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.6444 - mae: 7.6444
# Epoch 29/100
# 1/1 [==============================] - 0s 13ms/step - loss: 7.5119 - mae: 7.5119
# Epoch 30/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.3794 - mae: 7.3794
# Epoch 31/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7.2750 - mae: 7.2750
# Epoch 32/100
# 1/1 [==============================] - 0s 14ms/step - loss: 7.2694 - mae: 7.2694
# Epoch 33/100
# 1/1 [==============================] - 0s 16ms/step - loss: 7.2638 - mae: 7.2638
# Epoch 34/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.2581 - mae: 7.2581
# Epoch 35/100
# 1/1 [==============================] - 0s 18ms/step - loss: 7.2525 - mae: 7.2525
# Epoch 36/100
# 1/1 [==============================] - 0s 19ms/step - loss: 7.2469 - mae: 7.2469
# Epoch 37/100
# 1/1 [==============================] - 0s 19ms/step - loss: 7.2413 - mae: 7.2413
# Epoch 38/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.2356 - mae: 7.2356
# Epoch 39/100
# 1/1 [==============================] - 0s 13ms/step - loss: 7.2300 - mae: 7.2300
# Epoch 40/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.2244 - mae: 7.2244
# Epoch 41/100
# 1/1 [==============================] - 0s 16ms/step - loss: 7.2188 - mae: 7.2188
# Epoch 42/100
# 1/1 [==============================] - 0s 20ms/step - loss: 7.2131 - mae: 7.2131
# Epoch 43/100
# 1/1 [==============================] - 0s 10ms/step - loss: 7.2075 - mae: 7.2075
# Epoch 44/100
# 1/1 [==============================] - 0s 10ms/step - loss: 7.2019 - mae: 7.2019
# Epoch 45/100
# 1/1 [==============================] - 0s 12ms/step - loss: 7.1962 - mae: 7.1962
# Epoch 46/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7.1906 - mae: 7.1906
# Epoch 47/100
# 1/1 [==============================] - 0s 16ms/step - loss: 7.1850 - mae: 7.1850
# Epoch 48/100
# 1/1 [==============================] - 0s 37ms/step - loss: 7.1794 - mae: 7.1794
# Epoch 49/100
# 1/1 [==============================] - 0s 17ms/step - loss: 7.1737 - mae: 7.1737
# Epoch 50/100
# 1/1 [==============================] - 0s 12ms/step - loss: 7.1681 - mae: 7.1681
# Epoch 51/100
# 1/1 [==============================] - 0s 16ms/step - loss: 7.1625 - mae: 7.1625
# Epoch 52/100
# 1/1 [==============================] - 0s 29ms/step - loss: 7.1569 - mae: 7.1569
# Epoch 53/100
# 1/1 [==============================] - 0s 18ms/step - loss: 7.1512 - mae: 7.1512
# Epoch 54/100
# 1/1 [==============================] - 0s 13ms/step - loss: 7.1456 - mae: 7.1456
# Epoch 55/100
# 1/1 [==============================] - 0s 24ms/step - loss: 7.1400 - mae: 7.1400
# Epoch 56/100
# 1/1 [==============================] - 0s 33ms/step - loss: 7.1344 - mae: 7.1344
# Epoch 57/100
# 1/1 [==============================] - 0s 12ms/step - loss: 7.1287 - mae: 7.1287
# Epoch 58/100
# 1/1 [==============================] - 0s 19ms/step - loss: 7.1231 - mae: 7.1231
# Epoch 59/100
# 1/1 [==============================] - 0s 22ms/step - loss: 7.1175 - mae: 7.1175
# Epoch 60/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.1119 - mae: 7.1119
# Epoch 61/100
# 1/1 [==============================] - 0s 21ms/step - loss: 7.1062 - mae: 7.1062
# Epoch 62/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.1006 - mae: 7.1006
# Epoch 63/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.0950 - mae: 7.0950
# Epoch 64/100
# 1/1 [==============================] - 0s 20ms/step - loss: 7.0894 - mae: 7.0894
# Epoch 65/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.0838 - mae: 7.0838
# Epoch 66/100
# 1/1 [==============================] - 0s 22ms/step - loss: 7.0781 - mae: 7.0781
# Epoch 67/100
# 1/1 [==============================] - 0s 35ms/step - loss: 7.0725 - mae: 7.0725
# Epoch 68/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.0669 - mae: 7.0669
# Epoch 69/100
# 1/1 [==============================] - 0s 23ms/step - loss: 7.0613 - mae: 7.0613
# Epoch 70/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.0556 - mae: 7.0556
# Epoch 71/100
# 1/1 [==============================] - 0s 14ms/step - loss: 7.0500 - mae: 7.0500
# Epoch 72/100
# 1/1 [==============================] - 0s 112ms/step - loss: 7.0444 - mae: 7.0444
# Epoch 73/100
# 1/1 [==============================] - 0s 18ms/step - loss: 7.0388 - mae: 7.0388
# Epoch 74/100
# 1/1 [==============================] - 0s 20ms/step - loss: 7.0331 - mae: 7.0331
# Epoch 75/100
# 1/1 [==============================] - 0s 20ms/step - loss: 7.0275 - mae: 7.0275
# Epoch 76/100
# 1/1 [==============================] - 0s 35ms/step - loss: 7.0219 - mae: 7.0219
# Epoch 77/100
# 1/1 [==============================] - 0s 40ms/step - loss: 7.0163 - mae: 7.0163
# Epoch 78/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.0106 - mae: 7.0106
# Epoch 79/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.0050 - mae: 7.0050
# Epoch 80/100
# 1/1 [==============================] - 0s 35ms/step - loss: 6.9994 - mae: 6.9994
# Epoch 81/100
# 1/1 [==============================] - 0s 44ms/step - loss: 6.9938 - mae: 6.9938
# Epoch 82/100
# 1/1 [==============================] - 0s 15ms/step - loss: 6.9881 - mae: 6.9881
# Epoch 83/100
# 1/1 [==============================] - 0s 22ms/step - loss: 6.9825 - mae: 6.9825
# Epoch 84/100
# 1/1 [==============================] - 0s 15ms/step - loss: 6.9769 - mae: 6.9769
# Epoch 85/100
# 1/1 [==============================] - 0s 19ms/step - loss: 6.9713 - mae: 6.9713
# Epoch 86/100
# 1/1 [==============================] - 0s 15ms/step - loss: 6.9656 - mae: 6.9656
# Epoch 87/100
# 1/1 [==============================] - 0s 13ms/step - loss: 6.9600 - mae: 6.9600
# Epoch 88/100
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9544 - mae: 6.9544
# Epoch 89/100
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9488 - mae: 6.9488
# Epoch 90/100
# 1/1 [==============================] - 0s 21ms/step - loss: 6.9431 - mae: 6.9431
# Epoch 91/100
# 1/1 [==============================] - 0s 32ms/step - loss: 6.9375 - mae: 6.9375
# Epoch 92/100
# 1/1 [==============================] - 0s 25ms/step - loss: 6.9319 - mae: 6.9319
# Epoch 93/100
# 1/1 [==============================] - 0s 34ms/step - loss: 6.9262 - mae: 6.9262
# Epoch 94/100
# 1/1 [==============================] - 0s 48ms/step - loss: 6.9206 - mae: 6.9206
# Epoch 95/100
# 1/1 [==============================] - 0s 17ms/step - loss: 6.9150 - mae: 6.9150
# Epoch 96/100
# 1/1 [==============================] - 0s 31ms/step - loss: 6.9094 - mae: 6.9094
# Epoch 97/100
# 1/1 [==============================] - 0s 12ms/step - loss: 6.9038 - mae: 6.9038
# Epoch 98/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8981 - mae: 6.8981
# Epoch 99/100
# 1/1 [==============================] - 0s 13ms/step - loss: 6.8925 - mae: 6.8925
# Epoch 100/100
# 1/1 [==============================] - 0s 16ms/step - loss: 6.8869 - mae: 6.8869

# %%
X,y
# Out:
# (<tf.Tensor: shape=(8, 1), dtype=float32, numpy=
#  array([[-7.],
#         [-4.],
#         [-1.],
#         [ 2.],
#         [ 5.],
#         [ 8.],
#         [11.],
#         [14.]], dtype=float32)>,
#  <tf.Tensor: shape=(8, 1), dtype=float32, numpy=
#  array([[ 3.],
#         [ 6.],
#         [ 9.],
#         [12.],
#         [15.],
#         [18.],
#         [21.],
#         [24.]], dtype=float32)>)

# %%
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 203ms/step
# array([[29.739855]], dtype=float32)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(50, activation=None),
    tf.keras.layers.Dense(1)
])

model.compile(loss="mae",
              optimizer=tf.keras.optimizers.Adam(lr=0.01),
              metrics=["mae"])

model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1/1 [==============================] - 1s 649ms/step - loss: 11.7682 - mae: 11.7682
# Epoch 2/100
# 1/1 [==============================] - 0s 11ms/step - loss: 11.0963 - mae: 11.0963
# Epoch 3/100
# 1/1 [==============================] - 0s 45ms/step - loss: 10.4149 - mae: 10.4149
# Epoch 4/100
# 1/1 [==============================] - 0s 14ms/step - loss: 9.7212 - mae: 9.7212
# Epoch 5/100
# 1/1 [==============================] - 0s 26ms/step - loss: 9.0103 - mae: 9.0103
# Epoch 6/100
# 1/1 [==============================] - 0s 22ms/step - loss: 8.2778 - mae: 8.2778
# Epoch 7/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.5198 - mae: 7.5198
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9648 - mae: 6.9648
# Epoch 9/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.0672 - mae: 7.0672
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.3316 - mae: 7.3316
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.4673 - mae: 7.4673
# Epoch 12/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.5285 - mae: 7.5285
# Epoch 13/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.4012 - mae: 7.4012
# Epoch 14/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.1923 - mae: 7.1923
# Epoch 15/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9575 - mae: 6.9575
# Epoch 16/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.6953 - mae: 6.6953
# Epoch 17/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.4127 - mae: 6.4127
# Epoch 18/100
# 1/1 [==============================] - 0s 15ms/step - loss: 6.3048 - mae: 6.3048
# Epoch 19/100
# 1/1 [==============================] - 0s 23ms/step - loss: 6.2575 - mae: 6.2575
# Epoch 20/100
# 1/1 [==============================] - 0s 31ms/step - loss: 6.3981 - mae: 6.3981
# Epoch 21/100
# 1/1 [==============================] - 0s 14ms/step - loss: 6.4550 - mae: 6.4550
# Epoch 22/100
# 1/1 [==============================] - 0s 19ms/step - loss: 6.3999 - mae: 6.3999
# Epoch 23/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.2482 - mae: 6.2482
# Epoch 24/100
# 1/1 [==============================] - 0s 13ms/step - loss: 6.0104 - mae: 6.0104
# Epoch 25/100
# 1/1 [==============================] - 0s 24ms/step - loss: 5.7876 - mae: 5.7876
# Epoch 26/100
# 1/1 [==============================] - 0s 17ms/step - loss: 5.6809 - mae: 5.6809
# Epoch 27/100
# 1/1 [==============================] - 0s 20ms/step - loss: 5.5715 - mae: 5.5715
# Epoch 28/100
# 1/1 [==============================] - 0s 12ms/step - loss: 5.6123 - mae: 5.6123
# Epoch 29/100
# 1/1 [==============================] - 0s 13ms/step - loss: 5.6074 - mae: 5.6074
# Epoch 30/100
# 1/1 [==============================] - 0s 32ms/step - loss: 5.5541 - mae: 5.5541
# Epoch 31/100
# 1/1 [==============================] - 0s 10ms/step - loss: 5.4568 - mae: 5.4568
# Epoch 32/100
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3199 - mae: 5.3199
# Epoch 33/100
# 1/1 [==============================] - 0s 13ms/step - loss: 5.1477 - mae: 5.1477
# Epoch 34/100
# 1/1 [==============================] - 0s 20ms/step - loss: 4.9442 - mae: 4.9442
# Epoch 35/100
# 1/1 [==============================] - 0s 18ms/step - loss: 4.8239 - mae: 4.8239
# Epoch 36/100
# 1/1 [==============================] - 0s 36ms/step - loss: 4.7389 - mae: 4.7389
# Epoch 37/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.6657 - mae: 4.6657
# Epoch 38/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.5846 - mae: 4.5846
# Epoch 39/100
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4026 - mae: 4.4026
# Epoch 40/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.2652 - mae: 4.2652
# Epoch 41/100
# 1/1 [==============================] - 0s 31ms/step - loss: 4.1212 - mae: 4.1212
# Epoch 42/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.9701 - mae: 3.9701
# Epoch 43/100
# 1/1 [==============================] - 0s 36ms/step - loss: 3.8272 - mae: 3.8272
# Epoch 44/100
# 1/1 [==============================] - 0s 7ms/step - loss: 3.7042 - mae: 3.7042
# Epoch 45/100
# 1/1 [==============================] - 0s 11ms/step - loss: 3.5321 - mae: 3.5321
# Epoch 46/100
# 1/1 [==============================] - 0s 22ms/step - loss: 3.3664 - mae: 3.3664
# Epoch 47/100
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2116 - mae: 3.2116
# Epoch 48/100
# 1/1 [==============================] - 0s 7ms/step - loss: 3.0463 - mae: 3.0463
# Epoch 49/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8705 - mae: 2.8705
# Epoch 50/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6840 - mae: 2.6840
# Epoch 51/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4868 - mae: 2.4868
# Epoch 52/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2787 - mae: 2.2787
# Epoch 53/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0596 - mae: 2.0596
# Epoch 54/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8293 - mae: 1.8293
# Epoch 55/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5876 - mae: 1.5876
# Epoch 56/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3531 - mae: 1.3531
# Epoch 57/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0849 - mae: 1.0849
# Epoch 58/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8224 - mae: 0.8224
# Epoch 59/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5466 - mae: 0.5466
# Epoch 60/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2759 - mae: 0.2759
# Epoch 61/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1353 - mae: 0.1353
# Epoch 62/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4494 - mae: 0.4494
# Epoch 63/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6499 - mae: 0.6499
# Epoch 64/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6216 - mae: 0.6216
# Epoch 65/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.8035 - mae: 0.8035
# Epoch 66/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7995 - mae: 0.7995
# Epoch 67/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7409 - mae: 0.7409
# Epoch 68/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7807 - mae: 0.7807
# Epoch 69/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6305 - mae: 0.6305
# Epoch 70/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5556 - mae: 0.5556
# Epoch 71/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4306 - mae: 0.4306
# Epoch 72/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2787 - mae: 0.2787
# Epoch 73/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1378 - mae: 0.1378
# Epoch 74/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1193 - mae: 0.1193
# Epoch 75/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2777 - mae: 0.2777
# Epoch 76/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3244 - mae: 0.3244
# Epoch 77/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4157 - mae: 0.4157
# Epoch 78/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4320 - mae: 0.4320
# Epoch 79/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3390 - mae: 0.3390
# Epoch 80/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2968 - mae: 0.2968
# Epoch 81/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2356 - mae: 0.2356
# Epoch 82/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1632 - mae: 0.1632
# Epoch 83/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1340 - mae: 0.1340
# Epoch 84/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1261 - mae: 0.1261
# Epoch 85/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1703 - mae: 0.1703
# Epoch 86/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2123 - mae: 0.2123
# Epoch 87/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2288 - mae: 0.2288
# Epoch 88/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1900 - mae: 0.1900
# Epoch 89/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1354 - mae: 0.1354
# Epoch 90/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1219 - mae: 0.1219
# Epoch 91/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0382 - mae: 0.0382
# Epoch 92/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2196 - mae: 0.2196
# Epoch 93/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2188 - mae: 0.2188
# Epoch 94/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1427 - mae: 0.1427
# Epoch 95/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1169 - mae: 0.1169
# Epoch 96/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2068 - mae: 0.2068
# Epoch 97/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1523 - mae: 0.1523
# Epoch 98/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2134 - mae: 0.2134
# Epoch 99/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2330 - mae: 0.2330
# Epoch 100/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0780 - mae: 0.0780

# %%
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 76ms/step
# array([[26.583801]], dtype=float32)

# %% [markdown]
# ## Evaluating a model

# %%
X = tf.range(-100, 100, 4)
X
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
y = X+10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
import matplotlib.pyplot as plt

plt.scatter(X,y)

# %% [markdown]
# ### 3 Sets

# %%
X_train = X[:40]
y_train = y[:40]

X_test = X[40:]
y_test = y[40:]

# %%
plt.figure(figsize=(10,7))
plt.scatter(X_train, y_train, c="b", label="Training Data")
plt.scatter(X_test, y_test, c="g", label="Testing Data")
plt.legend()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# model.fit(X_train, y_train, epochs=100)

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, input_shape=[1], name="Input_layer"),
    tf.keras.layers.Dense(1, name="Output_layer")
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_layer (Dense)         (None, 10)                20
#
#  Output_layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=100, verbose=0)

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(model=model, show_shapes=True)

# %% [markdown]
# ### Visualizing our model's predictions

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 1/1 [==============================] - 0s 38ms/step
# array([[ 70.55219 ],
#        [ 75.139915],
#        [ 79.72764 ],
#        [ 84.31536 ],
#        [ 88.90308 ],
#        [ 93.49081 ],
#        [ 98.07853 ],
#        [102.66626 ],
#        [107.253975],
#        [111.841705]], dtype=float32)

# %%
def plot_predictions(train_data=X_train,
                     train_labels=y_train,
                     test_data=X_test,
                     test_labels=y_test,
                     predictions=y_pred):
  plt.figure(figsize=(10,7))
  plt.scatter(train_data,train_labels, c="b", label="Training Data")
  plt.scatter(test_data,test_labels, c="g", label="Testing Data")
  plt.scatter(test_data, predictions, c="r", label= "Predictions")
  plt.legend()

# %%
plot_predictions()

# %% [markdown]
# ### Evaluating our model’s prediction with regression evaluation metrics

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 216ms/step - loss: 3.1969 - mae: 3.1969
# [3.196946620941162, 3.196946620941162]

# %%
mae = tf.metrics.mean_absolute_error(y_test,tf.squeeze(y_pred))
mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.1969466>

# %%
mse = tf.metrics.mean_squared_error(y_test, tf.squeeze(y_pred))
mse
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=13.070175>

# %%
def mae(y_true, y_pred):
  return tf.metrics.mean_absolute_error(y_true,tf.squeeze(y_pred))

def mse(y_true, y_test):
  return tf.metrics.mean_squared_error(y_true, tf.squeeze(y_pred))

# %% [markdown]
# ### Running experiments to improve our model

# %%
tf.random.set_seed(42)

model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model_1.compile(loss=tf.keras.loses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=["mae"])
